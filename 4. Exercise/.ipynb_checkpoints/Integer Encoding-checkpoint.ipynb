# %% [markdown]
# ## Integer Encoding
#
# - 단어 토큰화 또는 형태소 토큰화를 수행했다면 각 단어에 고유한 정수를 부여한다.
#
# - 이때 중복은 허용하지 않는다.
#
# - 중복이 허용되지 않는 모든 단어들의 집합을 단어 집합(Vocabulary)이라고 한다.
#
# 참고 : https://wikidocs.net/31766

# %%
text = "A barber is a person. a barber is good person. a barber is huge person. \
        he Knew A Secret! The Secret He Kept is huge secret. Huge secret. His barber kept his word. a barber kept his word. \
        His barber kept his secret. But keeping and keeping such a huge secret to himself was driving the barber crazy. \
        the barber went up a huge mountain."

# %%
# nltk를 활용하여 문장 토큰화
from nltk.tokenize import sent_tokenize
text = sent_tokenize(text)
print(text)
# Out:
# ['A barber is a person.', 'a barber is good person.', 'a barber is huge person.', 'he Knew A Secret!', 'The Secret He Kept is huge secret.', 'Huge secret.', 'His barber kept his word.', 'a barber kept his word.', 'His barber kept his secret.', 'But keeping and keeping such a huge secret to himself was driving the barber crazy.', 'the barber went up a huge mountain.']

# %%
from nltk.corpus import stopwords

# %%
sentences = []
stop_words = set(stopwords.words('english'))

# %%
from nltk.tokenize import word_tokenize

# %%
for i in text :
    sentence = word_tokenize(i) # 단어 토큰화
    result = []
    
    for word in sentence :
        word = word.lower() # 모든 단어를 소문자화하여 단어의 개수를 줄임
        if word not in stop_words : # 불용어 제거
            if len(word) > 2 : # 단어 길이가 2이하인 경우에 추가로 단어 제거
                result.append(word)
    sentences.append(result)
print(sentences)
# Out:
# [['barber', 'person'], ['barber', 'good', 'person'], ['barber', 'huge', 'person'], ['knew', 'secret'], ['secret', 'kept', 'huge', 'secret'], ['huge', 'secret'], ['barber', 'kept', 'word'], ['barber', 'kept', 'word'], ['barber', 'kept', 'secret'], ['keeping', 'keeping', 'huge', 'secret', 'driving', 'barber', 'crazy'], ['barber', 'went', 'huge', 'mountain']]

# %% [markdown]
# ## Build Vocabulary

# %%
from collections import Counter

# %%
words = sum(sentences, []) # 1차원 리스트로 변환해주고
print(words)
# Out:
# ['barber', 'person', 'barber', 'good', 'person', 'barber', 'huge', 'person', 'knew', 'secret', 'secret', 'kept', 'huge', 'secret', 'huge', 'secret', 'barber', 'kept', 'word', 'barber', 'kept', 'word', 'barber', 'kept', 'secret', 'keeping', 'keeping', 'huge', 'secret', 'driving', 'barber', 'crazy', 'barber', 'went', 'huge', 'mountain']

# %%
# Counter를 사용해 단어의 모든 빈도를 계산
vocab = Counter(words)
print(vocab)
# Out:
# Counter({'barber': 8, 'secret': 6, 'huge': 5, 'kept': 4, 'person': 3, 'word': 2, 'keeping': 2, 'good': 1, 'knew': 1, 'driving': 1, 'crazy': 1, 'went': 1, 'mountain': 1})

# %%
print(vocab['barber']) # 'barber'라는 단어의 빈도수를 출력
# Out:
# 8

# %% [markdown]
# - 빈도수가 높은 순서대로 정렬하고, 빈도 수가 높을 수록 낮은 수의 정수를 부여한다.
#
# - 이렇게 진행할 경우 빈도 수가 낮은 단어들을 제외시키면서 단어 집합의 크기를 조절하기가 편해진다.

# %%
# 빈도수가 높은 순서대로 정렬
vocab_sorted = sorted(vocab.items(), key = lambda x : x[1] , reverse = True)
print(vocab_sorted)
# Out:
# [('barber', 8), ('secret', 6), ('huge', 5), ('kept', 4), ('person', 3), ('word', 2), ('keeping', 2), ('good', 1), ('knew', 1), ('driving', 1), ('crazy', 1), ('went', 1), ('mountain', 1)]

# %%
# 이제 높은 빈도수를 가진 단어일수록 낮은 정수 인덱스를 부여한다.
word2idx = {}
i = 0
for (word,frequency) in vocab_sorted :
    if frequency >  1 : # 빈도 수가 1일 경우 제외 
        i = i + 1 # 인코딩 번호 +1
        word2idx[word] = i
print(word2idx)
# Out:
# {'barber': 1, 'secret': 2, 'huge': 3, 'kept': 4, 'person': 5, 'word': 6, 'keeping': 7}

# %% [markdown]
# **텍스트 데이터에 있는 단어를 모두 사용하기 보다 빈도수가 가장 높은 n개의 단어만 사용해야 할 때도 있다.**<br>
# ex) 네이버 영화 리뷰 20만개중 단어 집합이 37000개일 경우(단어 집합이 많으면 많아질수록 딥러닝 모델이 터질 확률이 높다.)
#
#
# 위 단어들은 빈도수가 높은 순서대로 낮은 정수가 부여되어 있으므로 빈도수 상위 n개의 단어만 사용하고 싶다면 vocab에서 정수값이 1부터 n까지인 단어들만 사용하면 된다.

# %%
vocab_size = 5
words_frequency = [w for w,c in word2idx.items() if c >= vocab_size + 1] # 인덱스가 5 초과인 단어 제거
print(words_frequency) 
for w in words_frequency : # 해당 단어들의 정보를 삭제
    del word2idx[w]
print(word2idx)
# Out:
# ['word', 'keeping']
# {'barber': 1, 'secret': 2, 'huge': 3, 'kept': 4, 'person': 5}

# %% [markdown]
# 아래와 같이 'good' 같은 경우엔 상위 빈도 5개에 들어가지 않는 단어이다.
#
# 이처럼 단어 집합에 존재하지 않는 단어들을 Out - Of - Vocabulary(단어 집합에 없는 단어의 약자로 **'OOV'**라고 한다.

# %%
sentences[1]
# Out:
# ['barber', 'good', 'person']

# %% [markdown]
# word2idx에 'OOV'란 단어를 새롭게 추가하고, 단어 집합에 없는 단어들은 'OOV'의 인덱스로 인코딩했다.
#
# OOV는 일종의 상황에 대한 용어이고, UNK(Unknown)이라고 하기도 한다.

# %%
# OOV에 해당하는 정수 추가
word2idx['UNK'] = 6
print(word2idx)
# Out:
# {'barber': 1, 'secret': 2, 'huge': 3, 'kept': 4, 'person': 5, 'UNK': 6}

# %%
encoded = []

for s in sentences : # 단어 집합 반복 돌리면서
    temp = []
    for w in s : # 
        try : 
            temp.append(word2idx[w])
        except KeyError : # 단어가 word2idx에 존재하지않으면
            temp.append(word2idx['UNK']) # 'UNK'의 정수로 대체
    encoded.append(temp)
encoded
# Out:
# [[1, 5],
#  [1, 6, 5],
#  [1, 3, 5],
#  [6, 2],
#  [2, 4, 3, 2],
#  [3, 2],
#  [1, 4, 6],
#  [1, 4, 6],
#  [1, 4, 2],
#  [6, 6, 3, 2, 6, 1, 6],
#  [1, 6, 3, 6]]

# %% [markdown]
# ## Build Vocab & Integer Encoding(Tensorflow)
#
# - 방금 진행했던 Build Vocabulary와 Integer Encoding을 텐서플로가 제공하는 도구를 사용하면 훨씬 더 편하게 할 수 있다.

# %%
print(sentences)
# Out:
# [['barber', 'person'], ['barber', 'good', 'person'], ['barber', 'huge', 'person'], ['knew', 'secret'], ['secret', 'kept', 'huge', 'secret'], ['huge', 'secret'], ['barber', 'kept', 'word'], ['barber', 'kept', 'word'], ['barber', 'kept', 'secret'], ['keeping', 'keeping', 'huge', 'secret', 'driving', 'barber', 'crazy'], ['barber', 'went', 'huge', 'mountain']]

# %% [markdown]
# 텐서플로는 정수 인코딩을 수행하는 전처리 도구인 **keras.preprocessing.text.Tokenizer**를 제공한다.
#
# **fit_on_texts**는 입력한 텍스트로부터 단어 빈도수가 높은 순으로 낮은 정수 인덱스를 부여하는데, 앞에서 진행한 과정과 동일하다고 보면 된다.
#
# 각 단어에 인덱스가 어떻게 부여되는지를 보려면, **word_index**를 사용한다.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

tokenizer.fit_on_texts(sentences) 
# fit_on_texts()안에 코퍼스를 입력으로 하면 빈도수를 기준으로 단어 집합을 생성한다.

# %%
# 생성된 단어집합
print(tokenizer.word_index)
# Out:
# {'barber': 1, 'secret': 2, 'huge': 3, 'kept': 4, 'person': 5, 'word': 6, 'keeping': 7, 'good': 8, 'knew': 9, 'driving': 10, 'crazy': 11, 'went': 12, 'mountain': 13}

# %% [markdown]
# 이전에 만들었던 단어 집합과 동일한 결과가 나왔다.

# %%
# 이전에 만들었던 단어 집합
print(word2idx)
# Out:
# {'barber': 1, 'secret': 2, 'huge': 3, 'kept': 4, 'person': 5, 'UNK': 6}

# %% [markdown]
# 각 단어의 빈도수가 높은 순서대로 인덱스가 부여된 것을 확인할 수 있다.
#
# 각 단어가 카운트를 수행했을 때 몇 개였는지를 보고자 한다면 **word_counts**를 사용한다.

# %%
# 단어의 빈도 수 확인 barber의 빈도수가 가장 높기 때문에 1, 그 다음 최빈값(person) 2 순으로 전개
print(tokenizer.word_counts)
# Out:
# OrderedDict([('barber', 8), ('person', 3), ('good', 1), ('huge', 5), ('knew', 1), ('secret', 6), ('kept', 4), ('word', 2), ('keeping', 2), ('driving', 1), ('crazy', 1), ('went', 1), ('mountain', 1)])

# %% [markdown]
# **text_to_sequences()**는 입력으로 들어온 코퍼스에 대해서 각 단어를 이미 정해진 인덱스로 변환한다.

# %%
print(tokenizer.texts_to_sequences(sentences))
# Out:
# [[1, 5], [1, 8, 5], [1, 3, 5], [9, 2], [2, 4, 3, 2], [3, 2], [1, 4, 6], [1, 4, 6], [1, 4, 2], [7, 7, 3, 2, 10, 1, 11], [1, 12, 3, 13]]

# %% [markdown]
# 마찬가지로 케라스 토크나이저에서도 빈도수가 높은 상위 몇 개의 단어만 사용하겠다고 지정할 수 있다.
#
# 상위 5개 단어를 사용해보자.

# %%
vocab_size = 5

tokenizer = Tokenizer(num_words = vocab_size + 1) # 상위 5개 단어만 사용
tokenizer.fit_on_texts(sentences)

# %% [markdown]
# **num_words에서 +1을 더해주는 이유는 뒤에서 진행할 padding에서 '0을 사용할 거라고 임의적으로 명시해주기 때문이다.**

# %%
print(tokenizer.texts_to_sequences(sentences))
# Out:
# [[1, 5], [1, 5], [1, 3, 5], [2], [2, 4, 3, 2], [3, 2], [1, 4], [1, 4], [1, 4, 2], [3, 2, 1], [1, 3]]

# %% [markdown]
# **'OOV'도 지정이 가능하다!**

# %%
vocab_size = 5
print(sentences[1])
tokenizer = Tokenizer(num_words = vocab_size + 2, oov_token = 'OOV') # OOV 지정시 + 2 , 숫자 0과 OOV
tokenizer.fit_on_texts(sentences)
print(tokenizer.texts_to_sequences(sentences))
# Out:
# ['barber', 'good', 'person']
# [[2, 6], [2, 1, 6], [2, 4, 6], [1, 3], [3, 5, 4, 3], [4, 3], [2, 5, 1], [2, 5, 1], [2, 5, 3], [1, 1, 4, 3, 1, 2, 1], [2, 1, 4, 1]]

# %% [markdown]
# 케라스에서의 OOV는 1로 지정된다.
#
# 빈도수 상위 5개의 단어는 2 ~ 6까지의 인덱스를 가졌으며, 그 외 단어 집합에 없는 'good'과 같은 단어들은 전부 'OOV'의 인덱스인 1로 인코딩 되었다.

# %%
print('단어 OOV의 인덱스 : {}'.format(tokenizer.word_index['OOV']))
# Out:
# 단어 OOV의 인덱스 : 1

# %% [markdown]
# ## 직접 토큰화부터 정수인코딩까지 해보기
#
# - 데이터셋 : 네이버 리뷰 데이터 사용

# %%
# 라이브러리 호출
import pandas as pd
import numpy as np
import urllib.request
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# urlretrieve : URL로 표시된 네트워크 객체를 로컬 파일로 복사한다.
# 참고 : https://docs.python.org/ko/3/library/urllib.request.html
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x1cb12838040>)

# %%
train_data = pd.read_table('ratings_test.txt')

# %%
train_data.head()
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %%
# 리뷰 개수
len(train_data)
# Out:
# 50000

# %%
# 리뷰 중복 개수 확인
len(train_data) - train_data['document'].nunique()
# Out:
# 843

# %%
train_data.drop_duplicates(subset = ['document'], inplace = True) # 중복 제거
train_data = train_data.dropna(how = 'any') # null 값이 존재하는 행 제거

# %%
# 중복 제거한 샘플 개수
len(train_data)
# Out:
# 49157

# %%
# 정규 표현식으로 온전한 한글이 아니면 제외
import re
train_data['document'] = train_data['document'].apply(lambda x : re.sub(r'[^3D 4Dㅏ-ㅣ 가-힣]','',x))

# %%
train_data
# Out:
#             id                                       document  label
# 0      6270596                                             굳       1
# 1      9274899                                              D      0
# 2      8544678               뭐야 이 평점들은 나쁘진 않지만 점 짜리는 더더욱 아니잖아      0
# 3      6825595                      지루하지는 않은데 완전 막장임 돈주고 보기에는      0
# 4      6723715  3D만 아니었어도 별 다섯 개 줬을텐데 왜 3D로 나와서 제 심기를 불편하게 하죠      0
# ...        ...                                            ...    ...
# 49995  4608761        오랜만에 평점 로긴했네 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 49996  5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따       0
# 49997  9072549                그림도 좋고 완성도도 높았지만 보는 내내 불안하게 만든다      0
# 49998  5802125     절대 봐서는 안 될 영화 재미도 없고 기분만 잡치고 한 세트장에서 다 해먹네      0
# 49999  6070594                                     마무리는 또 왜이래      0
#
# [49157 rows x 3 columns]

# %%
# 빈 공백으로 변한 리뷰는 결측치로 변환
train_data['document'].replace('',np.nan, inplace = True)
print(train_data.isnull().sum())
# Out:
# id            0
# document    191
# label         0
# dtype: int64

# %%
# 결측값 제거
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 48966

# %%
# 불용어 정의
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
from konlpy.tag import Mecab

# %%
# 형태소 분석기는 mecab 사용
mecab = Mecab('C:\mecab\mecab-ko-dic')

# %%
# 불용어 제거
X_train = []

for sentence in train_data['document'] :
    temp_x = mecab.morphs(sentence)
    temp_x = [word for word in temp_x if word not in stopwords]
    X_train.append(temp_x)

# %%
X_train[:5]
# Out:
# [['굳'],
#  ['D'],
#  ['뭐', '야', '평점', '나쁘', '진', '않', '지만', '점', '짜리', '더더욱', '아니', '잖아'],
#  ['지루', '하', '지', '않', '은데', '완전', '막장', '임', '돈', '주', '고', '보', '기'],
#  ['3',
#   'D',
#   '만',
#   '아니',
#   '었',
#   '어도',
#   '별',
#   '다섯',
#   '개',
#   '줬',
#   '을',
#   '텐데',
#   '왜',
#   '3',
#   'D',
#   '로',
#   '나와서',
#   '제',
#   '심기',
#   '불편',
#   '하',
#   '게',
#   '하',
#   '죠']]

# %%
# 정수 인코딩 진행
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'영화': 1, '다': 2, '고': 3, '하': 4, '을': 5, '보': 6, '게': 7, '지': 8, '있': 9, '없': 10, '좋': 11, '나': 12, '었': 13, '만': 14, '는데': 15, '너무': 16, '봤': 17, '안': 18, '적': 19, '로': 20, '정말': 21, '것': 22, '음': 23, '재밌': 24, '아': 25, '진짜': 26, '네요': 27, '어': 28, '같': 29, '지만': 30, '했': 31, '에서': 32, '기': 33, '점': 34, '네': 35, '거': 36, '았': 37, '않': 38, '수': 39, '되': 40, '면': 41, '인': 42, '연기': 43, '말': 44, '평점': 45, '주': 46, '최고': 47, '내': 48, '던': 49, '이런': 50, '어요': 51, '왜': 52, '할': 53, '해': 54, '아니': 55, '듯': 56, '습니다': 57, '그': 58, '겠': 59, '더': 60, '생각': 61, '스토리': 62, '싶': 63, '사람': 64, '드라마': 65, '때': 66, '감동': 67, '까지': 68, '보다': 69, '볼': 70, '배우': 71, '내용': 72, '본': 73, '함': 74, '감독': 75, '만들': 76, '알': 77, '중': 78, '라': 79, '그냥': 80, '뭐': 81, '재미': 82, '시간': 83, '지루': 84, '재미있': 85, '사랑': 86, '년': 87, '였': 88, '서': 89, '냐': 90, '잼': 91, '재미없': 92, '못': 93, '번': 94, '3': 95, '라고': 96, '다시': 97, '쓰레기': 98, '나오': 99, '면서': 100, '니': 101, '끝': 102, '작품': 103, '하나': 104, '이거': 105, '해서': 106, '야': 107, '이건': 108, '기대': 109, '줄': 110, '남': 111, '임': 112, '마지막': 113, '개': 114, '액션': 115, '다는': 116, '정도': 117, '라는': 118, '많': 119, '으면': 120, '참': 121, '완전': 122, '건': 123, '처음': 124, '입니다': 125, '분': 126, '장면': 127, '지금': 128, '다가': 129, '이렇게': 130, 'ㅠㅠ': 131, '아깝': 132, '이게': 133, '이야기': 134, '최악': 135, '성': 136, '모르': 137, '시': 138, '된': 139, '님': 140, '돈': 141, '느낌': 142, '일': 143, '어서': 144, '편': 145, '애': 146, '다고': 147, '이해': 148, '별로': 149, '이상': 150, '여자': 151, '봐도': 152, '전': 153, '에게': 154, '부터': 155, '넘': 156, '두': 157, '인데': 158, '한국': 159, '많이': 160, '만든': 161, '난': 162, '우리': 163, '역시': 164, '명작': 165, '걸': 166, '는지': 167, 'ㅡㅡ': 168, '또': 169, '주인공': 170, '대': 171, '합니다': 172, '그리고': 173, '때문': 174, '괜찮': 175, '연출': 176, '받': 177, '4': 178, '살': 179, '한다': 180, '기억': 181, '엔': 182, '꼭': 183, '저': 184, '현실': 185, '요': 186, '길': 187, '긴': 188, '죽': 189, '재': 190, '인생': 191, '공포': 192, '이나': 193, '랑': 194, '짜증': 195, '무슨': 196, '남자': 197, '마음': 198, '내내': 199, '데': 200, '며': 201, '속': 202, '아요': 203, '세요': 204, '오': 205, '결말': 206, '수준': 207, '짱': 208, '낮': 209, '아이': 210, '씨': 211, '인간': 212, '아서': 213, '필요': 214, '전개': 215, '반전': 216, '맞': 217, '다니': 218, '다른': 219, '뿐': 220, '소재': 221, '가슴': 222, '일본': 223, '매력': 224, '높': 225, '굿': 226, '만드': 227, '눈물': 228, '유치': 229, '노': 230, '준': 231, '실망': 232, '별': 233, '음악': 234, '밋': 235, '보여': 236, '웃': 237, '은데': 238, '없이': 239, '용': 240, '인지': 241, '추천': 242, '아직': 243, '자체': 244, '인가': 245, '아닌': 246, '울': 247, '란': 248, '모든': 249, '가장': 250, '화': 251, '쓰': 252, '몇': 253, '코미디': 254, '모습': 255, '대한': 256, '신': 257, '는다': 258, '원작': 259, '될': 260, '모두': 261, '처럼': 262, '계속': 263, '찍': 264, '시리즈': 265, '마': 266, '다면': 267, '나라': 268, '을까': 269, '급': 270, '캐릭터': 271, '그래도': 272, '건지': 273, '죠': 274, '스럽': 275, '된다': 276, '연기력': 277, '극장': 278, '가족': 279, '솔직히': 280, '눈': 281, '비': 282, '대박': 283, '그런': 284, '아주': 285, '여': 286, '대사': 287, '대단': 288, '이제': 289, '표현': 290, '여운': 291, '그렇': 292, '뭔가': 293, '나왔': 294, '기분': 295, '진심': 296, '이걸': 297, '개봉': 298, '부분': 299, '공감': 300, '구': 301, '몰입': 302, '전혀': 303, '근데': 304, '해도': 305, '후': 306, '제': 307, '작': 308, '이랑': 309, '타임': 310, '먹': 311, '싫': 312, '제목': 313, '진': 314, '삶': 315, '친구': 316, '바': 317, '치': 318, '조금': 319, 'ㅠ': 320, '요즘': 321, '중간': 322, '물': 323, '가지': 324, '어떻게': 325, '딱': 326, 'ㅜㅜ': 327, '찾': 328, '작가': 329, '나름': 330, '사': 331, '특히': 332, '긴장감': 333, '봄': 334, '잔잔': 335, '막장': 336, '해요': 337, '아쉽': 338, '따뜻': 339, '웃기': 340, '놈': 341, '부족': 342, '놓': 343, '차라리': 344, '영상': 345, '날': 346, '노래': 347, '시작': 348, '어디': 349, '구나': 350, '한테': 351, '믿': 352, '시대': 353, '씬': 354, '당시': 355, '라도': 356, '이유': 357, '이것': 358, '제일': 359, '봐야': 360, '무섭': 361, '아까운': 362, '아름다운': 363, '보이': 364, '라면': 365, '의미': 366, '명': 367, '같이': 368, '스릴러': 369, '개인': 370, '점수': 371, '훌륭': 372, '잇': 373, '오랜만': 374, '니까': 375, '만큼': 376, '답': 377, '세상': 378, '전쟁': 379, '엄청': 380, '슬프': 381, '엔딩': 382, '제대로': 383, '강추': 384, '더라': 385 ...

# %%
print(tokenizer.word_index['영화'])
# Out:
# 1

# %%
# 단어 출현 빈도수
print(tokenizer.word_counts)
# Out:
# OrderedDict([('굳', 134), ('d', 161), ('뭐', 1359), ('야', 955), ('평점', 2200), ('나쁘', 80), ('진', 302), ('않', 2555), ('지만', 2891), ('점', 2606), ('짜리', 155), ('더더욱', 6), ('아니', 1819), ('잖아', 114), ('지루', 1294), ('하', 14967), ('지', 6260), ('은데', 427), ('완전', 830), ('막장', 275), ('임', 894), ('돈', 716), ('주', 2188), ('고', 15657), ('보', 8479), ('기', 2644), ('3', 1119), ('만', 3947), ('었', 4073), ('어도', 236), ('별', 438), ('다섯', 43), ('개', 890), ('줬', 173), ('을', 9916), ('텐데', 134), ('왜', 1864), ('로', 3274), ('나와서', 154), ('제', 313), ('심기', 1), ('불편', 107), ('게', 7560), ('죠', 353), ('음악', 437), ('된', 734), ('최고', 2142), ('영화', 19561), ('진정', 142), ('쓰레기', 1058), ('마치', 71), ('미국', 215), ('애니', 172), ('에서', 2680), ('튀어나온', 3), ('듯', 1810), ('창의', 6), ('력', 48), ('없', 5391), ('로봇', 35), ('디자인', 20), ('부터', 668), ('고개', 13), ('젖', 32), ('한다', 594), ('갈수록', 187), ('개판', 57), ('되', 2482), ('중국', 162), ('유치', 445), ('내용', 1478), ('음', 3106), ('폼', 26), ('잡', 194), ('다', 18403), ('끝', 1011), ('남', 903), ('말', 2245), ('안', 3435), ('무기', 18), ('남무', 1), ('아', 2949), ('그립', 53), ('동사서독', 2), ('같', 2902), ('이건', 921), ('류', 180), ('아류', 37), ('작', 313), ('이별', 20), ('아픔', 42), ('뒤', 187), ('찾아오', 6), ('새로운', 93), ('인연', 20), ('기쁨', 10), ('모든', 401), ('사람', 1707), ('그렇', 331), ('네', 2600), ('괜찮', 614), ('네요', 2920), ('오랜만', 252), ('포켓몬스터', 4), ('잼', 1195), ('밌어요', 3), ('한국', 662), ('독립영화', 67), ('한계', 52), ('그렇게', 207), ('아버지', 121), ('된다', 351), ('비교', 154), ('됨', 220), ('청춘', 75), ('아름답', 210), ('그', 1795), ('아름다움', 39), ('이성', 15), ('흔들', 8), ('어', 2903), ('놓', 270), ('는다', 375), ('찰나', 4), ('포착', 2), ('섬세', 43), ('아름다운', 261), ('수채화', 6), ('퀴어', 8), ('눈', 346), ('보이', 261), ('반전', 477), ('흡인력', 5), ('사라지', 25), ('았', 2576), ('스토리', 1739), ('연출', 613), ('연기', 2342), ('비주얼', 46), ('등', 225), ('기본', 52), ('조차', 88), ('무슨', 525), ('평', 147), ('해', 1822), ('이런', 1967), ('찍', 370), ('김문옥', 1), ('감독', 1434), ('내', 2081), ('경력', 10), ('몇', 393), ('인데', 663), ('조무래기', 2), ('평론', 11), ('마인드', 20), ('빠져', 82), ('있', 5541), ('겠', 1784), ('소위', 3), ('문가', 2), ('라는', 877), ('냐', 1199), ('발연기', 125), ('도저히', 71), ('못', 1138), ('진짜', 2932), ('이렇게', 791), ('할', 1833), ('거', 2577), ('라곤', 35), ('상상', 119), ('못했', 93), ('나이스', 1), ('재미', 1358), ('우려먹', 32), ('챔프', 1), ('방송', 156), ('번', 1138), ('했', 2690), ('더라', 239), ('일', 707), ('금요일', 10), ('나이트메어', 5), ('시리즈', 370), ('함께', 199), ('가장', 399), ('많', 837), ('양산', 5), ('해냈', 3), ('던', 1987), ('헬', 6), ('레이저', 3), ('첫', 168), ('편', 699), ('작가', 282), ('상상력', 56), ('돋보이', 47), ('작품', 1006), ('며', 518), ('갈고리', 1), ('사', 280), ('찢', 12), ('고어', 24), ('씬', 264), ('지금', 809), ('더라도', 62), ('상당히', 127), ('잔인', 142), ('충격', 180), ('적', 3383), ('나름', 282), ('교훈', 120), ('돋', 147), ('어쩔', 98), ('수', 2492), ('없이', 425), ('저', 563), ('받', 604), ('밖에', 196), ('저질', 76), ('섹스', 67), ('코미디', 392), ('꽤', 146), ('재밌', 2971), ('본', 1475), ('였', 1229), ('민주', 10), ('화', 397), ('시대', 265), ('억눌린', 3), ('영혼', 40), ('관음', 2), ('인', 2397), ('욕구', 12), ('분출', 1), ('인상', 183), ('일본', 463), ('천황', 4), ('으로부터', 15), ('면죄부', 2), ('긴박', 24), ('과정', 82), ('루즈', 24), ('지저분', 13), ('늘어놓', 9), ('괜히', 87), ('나올', 169), ('때', 1688), ('어미', 3), ('알', 1394), ('건', 830), ('드려서', 2), ('긁', 7), ('부스', 3), ('름', 1), ('만들', 1421), ('다는', 882), ('분', 816), ('아래', 38), ('던데', 194), ('제대로', 240), ('봤', 3495), ('딱', 287), ('까지', 1556), ('면서', 1025), ('새끼', 91), ('나오', 1026), ('려', 118), ('그냥', 1362), ('면', 2465), ('놈', 271), ('한테', 266), ('당했', 23), ('것', 3121), ('두', 664), ('막', 118), ('뻔', 227), ('했으니', 11), ('작살낼', 1), ('밖', 187), ('번은', 4), ('어쩜', 41), ('을까', 364), ('실화', 145), ('라서', 172), ('더욱', 88), ('찡', 43), ('많이', 656), ('울', 406), ('어요', 1893), ('벌써', 67), ('4', 601), ('년', 1233), ('란', 403), ('시간', 1314), ('흘렀', 28), ('노', 445), ('답', 248), ('대', 633), ('어린이', 70), ('본받', 4), ('아라', 49), ('중', 1394), ('마음', 522), ('따뜻', 272), ('너무너무', 109), ('후회', 182), ('ㅠㅠ', 777), ('싫', 303), ('배우', 1496), ('나', 4365), ('이나', 534), ('영화판', 14), ('봐', 213), ('으면' ...

# %%
encoded = tokenizer.texts_to_sequences(X_train)

# %%
# 정수 인코딩 진행 결과
print(X_train[:5])
print(encoded[:5])
# Out:
# [['굳'], ['D'], ['뭐', '야', '평점', '나쁘', '진', '않', '지만', '점', '짜리', '더더욱', '아니', '잖아'], ['지루', '하', '지', '않', '은데', '완전', '막장', '임', '돈', '주', '고', '보', '기'], ['3', 'D', '만', '아니', '었', '어도', '별', '다섯', '개', '줬', '을', '텐데', '왜', '3', 'D', '로', '나와서', '제', '심기', '불편', '하', '게', '하', '죠']]
# [[661], [548], [81, 107, 45, 971, 314, 38, 30, 34, 571, 6155, 55, 729], [84, 4, 8, 38, 238, 122, 336, 112, 141, 46, 3, 6, 33], [95, 548, 14, 55, 13, 389, 233, 1555, 114, 513, 5, 662, 52, 95, 548, 20, 576, 307, 16139, 763, 4, 7, 4, 274]]

# %% [markdown]
# ## Padding
#
# - 모든 문장에 대해서 정수 인코딩을 수행했을 때 길이는 서로 다를 수 있다.
#
# - 이때 가상의 단어를 추가하여 길이를 맞춰준다.
#
# - 이렇게 하면 기계가 이를 병렬 연산할 수 있다.

# %% [markdown]
# ## One - Hot - Encoding
#
# - **원-핫 인코딩은 전체 단어 집합의 크기(중복은 카운트하지 않은 단어들의 개수)를 벡터의 차원으로 가진다.**
#
# - 각 단어에 고유한 정수 인덱스를 부여하고, 해당 인덱스의 원소는 1, 나머지 원소는 0을 가지는 벡터로 만든다.

# %% [markdown]
# ## Document Term Matrix - DTM
#
# - DTM은 마찬가지로 벡터가 단어 집합의 크기를 가지며, 대부분의 원소가 0을 가진다.
#
# - 각 단어는 고유한 정수 인덱스를 가지며, 해당 단어가 등장 횟루를 해당 인덱스의 값으로 가진다.
